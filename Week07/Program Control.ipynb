# %% [markdown]
# # Pseudo Code

# %% [markdown]
# In computer science, pseudocode is a plain language description of the steps in an algorithm or another system. Pseudocode often uses structural conventions of a normal programming language, but is intended for human reading rather than machine reading. It typically omits details that are essential for machine understanding of the algorithm, such as variable declarations and language-specific code. The programming language is augmented with natural language description details, where convenient, or with compact mathematical notation. The purpose of using pseudocode is that it is easier for people to understand than conventional programming language code, and that it is an efficient and environment-independent description of the key principles of an algorithm. It is commonly used in textbooks and scientific publications to document algorithms and in planning of software and other algorithms... Wikipedia

# %% [markdown]
# # Basic components of a pseudo code.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Basics of Relational Operators

# %% [raw]
# 1. ==
#
# 2. !=
#
# 3. >=
#
# 4. <=
#
# 5. >
#
# 6. <

# %% [raw]
# Question :
#     If I get above 90 in CSC106; I will get an A.

# %% [markdown]
# # Basics of Logical Operators

# %% [raw]
# 1. and
#
# 2. or
#
# 3. not

# %% [raw]
# Question :
#     If I get above 90 in CSC106 and CSC106L ; I will get an A.

# %% [markdown]
# # Example : Develop a pseudocode

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # IF

# %% [raw]
# Question :
#     Using IF statements, how do we address the above temperature checks.
#
# Syntax : if( condition ):
#              do something ..
#
# Good Programming Practise (GPP) :
#         Indentation
#         Documentation

# %%
Temp = int(input())
Age_Cat = input()
# Out:
# 1
# 1

# %%
print(type(Temp))
print(type(Age_Cat))
# Out:
# <class 'int'>
# <class 'str'>

# %%
if ( (Temp < 95) and (Age_Cat == 'Adult') ):
    print("Hypothermia : Seek Care")

# %% [raw]
# Question :
#
# Complete the rest of the program for Babies and Children.

# %% [raw]
# Question :

# %% [markdown]
# # IF .. ELSE

# %%
if b < a:
print("b is greater than a")
elif a == b:
print("a and b are the same")
# Out:
#   Cell In[27], line 2
#     print("b is greater than a")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [raw]
# Question :
#
#     1. Guess the values of a and b if we do NOT want to get any output.
#
#     2. Is this Good Programming Practise (GPP).
#
#     3. Did we address all the possible scenarions; for any possible mistakes.
#        Recode using GPP and all the possible scenario possibles.

# %% [markdown]
# # IF .. ELIF .. ELSE

# %% [raw]
# Complete the code for the above example using the template below :
#
# if :
#
# elif :
#
# else:

# %% [markdown]
# # Design a Calculator

# %%
#Compute the square root of 4.
import math
math.sqrt(4)
#sqrt(4)
# Out:
# 2.0

# %%
#Check for a number. 
Number = '100.OO'
NumberD = Number.isnumeric()
print(NumberD)

if(NumberD == 1):
    print("Its a number")
# Out:
# False

# %% [raw]
# Design Requirements: Design Thinking
#
# 0. Use import math and isnumeric functions.
#
# 1. Check that the numbers are within range (0 - 9) and is numeric. (10 points)
#
# 2. If doing Numerical operations, input numbers (10 points)
#    and if doing Addition, Subtraction, Multiplication and Division.
#    Process and Compute the result.
#
# 3. If  doing Trigonometry operations, input number(10 points)
#    and if doing sin, cos and tan.
#    Compute the result.
#
# 4. Extra-Credit : (10 points)
#    How can you design a M+, MC and MR function.
#    Where M+ is to add to memory, MC is to clear memory and MR is to recall from memory.
#    CLUE : What should the precedence be for this operations.

# %% [markdown]
# # while Loop

# %% [raw]
# syntax : while

# %% [raw]
# Example 1
#
# 1. SET an initial value.
# 2. CHECK - Is the condition(initial value) met?
#       If TRUE..
#       If FALSE ..
# 3. Change the value.

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [raw]
# Question : Modify the code to produce only the ODD numbers using IF statements.

# %% [markdown]
# # Break statement

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %% [raw]
# Question : Modify the code such that it breaks when the value is '0'.

# %% [markdown]
# # Continue statement

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [raw]
# Question : Modify the code to skip only the EVEN numbers; using IF statements.

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %% [raw]
# Question : what is the ouput of this program.

# %% [markdown]
# # Challenge : Design thinking

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Using an 8 bit LED display, where the positional value dictates an ON LED action.
# (assume the remaining LED positions are OFF).
#
# Using While LOOPS,
# 1. ON the LED from LEFT to RIGHT.
# 2. ON the LED from RIGHT to LEFT.
# repeat this 3 times.
#
# USE the folliwng code to slow the output :
#
# import time
# time.sleep(2.5)

# %%
import time

i = 1
while i < 6:
  print(i)
  time.sleep(2.5)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [raw]
# #RUN this if you get an error!
# #pip install termcolor

# %%
from termcolor import colored

display = [1,2,3,4,5,6,7,8]
display[0] = colored(' ', 'black', attrs=['reverse', 'blink'])
display[1] = colored(' ', 'black', attrs=['reverse', 'blink'])
display[2] = colored('*', 'red', attrs=['reverse', 'blink'])

print(display[0] ,display[1],display[2])
# Out:
#     *

# %% [markdown]
# # For Loops

# %% [raw]
# syntax : for var_name in data_container:

# %%
#example

grades = ['A', ' ', 'C', 'F']
for x in grades:
    print(x)
# Out:
# A
#
# C
# F

# %% [raw]
# Question : Write a for loop to iterate through this items.
#            - First_Name, Middle_Name, Last_Name.
#            condition : We do not have a middle name.

# %%
for x in "University of Mary":
    print(x)
# Out:
# U
# n
# i
# v
# e
# r
# s
# i
# t
# y
#
# o
# f
#
# M
# a
# r
# y

# %%
grades = ['A', 'B ', 'C', 'F']
for x in grades:
  print(x)
  if x == 'B':
    break
    
#Question : How does break work; when I come across 'B'.
# Out:
# A
# B
# C
# F

# %% [raw]
# Question : Write a for loop to iterate through this items.
#            - First_Name, Middle_Name, Last_Name.
#            condition : use continue, skip the Middle_Name; we do not have a Middle_Name.

# %%
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(2, 6):
  print(x)

#What is the output?
# Out:
# 2
# 3
# 4
# 5

# %% [raw]
# #Question : Generate numbers in this sequence .. 1,3,5,..21
#
# for x in range( , , ):
#   print(x)

# %%
#example : 

for x in range(6):
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# Finally finished!

# %%
for x in range(6):
  if x == 3: break
  print(x)
else:
  print("Finally finished!")

#Question : What is the output?
# Out:
# 0
# 1
# 2

# %% [raw]
# Question : Create this output using 2 for loops.
#
#             Tom 90
#             Mary 100
#             Jack 95

# %%
names = ['Tom', 'Mary', 'Jack']
grades = [90, 100, 95]

for x in range(3):
    for y in range(1):
        
        print(names[x], grades[x])
# Out:
# Tom 90
# Mary 100
# Jack 95

# %% [markdown]
# # Challenge

# %% [markdown]
# 1. an·​a·​gram ˈa-nə-ˌgram. 1. : a word or phrase made by transposing the letters of another word or phrase.
#
# The word "secure" is an anagram of "rescue."

# %% [raw]
# Question 1 : Write a program to check for this anagram - CAT.

# %%
#clue : logical rearrangement of data points.

# %% [raw]
# Question 2 : Write a program to check for this anagrams.

# %% [raw]
# Try this examples :
#
# 1.dormitory      – ____________________________
#
# 2.the Morse Code – ____________________________
#
# 3.Fourth of July – ____________________________
