# %%
import pandas as pd

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None) 

raw_df.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)


raw_df.plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)


raw_df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import pandas as pd

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)


raw_df.plot.box()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)


raw_df.plot.area()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)



raw_df.plot.scatter(x= 0, y = 1)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
import pandas as pd

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

raw_df.plot.pie(x= 0, y = 1)
# Out:
# <AxesSubplot:ylabel='1'>
