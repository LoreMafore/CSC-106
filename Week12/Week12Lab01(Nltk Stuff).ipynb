# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize

about = """

I love Gwenhwyfar Maragert Sieve. I will marry here in the next 2 years and have a billion babies with her.
"""

#sent_tokenize(about)
word_tokenize(about)
# Out:
# [nltk_data] Downloading package punkt to /home/conrad/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['I',
#  'love',
#  'Gwenhwyfar',
#  'Maragert',
#  'Sieve',
#  '.',
#  'I',
#  'will',
#  'marry',
#  'here',
#  'in',
#  'the',
#  'next',
#  '2',
#  'years',
#  'and',
#  'have',
#  'a',
#  'billion',
#  'babies',
#  'with',
#  'her',
#  '.']

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

about = """

I love Gwenhwyfar Maragert Sieve. I will marry here in the next 2 years and have a billion babies with her.
"""

about_Tokenized = word_tokenize(about)
about_Tokenized

stop_words = set(stopwords.words("english"))
filtered_list = []

for word in about_Tokenized:
    if word.casefold() not in stop_words:
        filitered_list.append(word)
        
filtered_list = [
    word for word in about_Tokenized if word.casefold() not in stop_words
    ]

filtered_list
# Out:
# [nltk_data] Downloading package stopwords to /home/conrad/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2861/3829054843.py in <module>
#      17 for word in about_Tokenized:
#      18     if word.casefold() not in stop_words:
# ---> 19         filitered_list.append(word)
#      20
#      21 filtered_list = [
#
# NameError: name 'filitered_list' is not defined

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

about = """

I love Gwenhwyfar Maragert Sieve. I will marry here in the next 2 years and have a billion babies with her.
"""

words = word_tokenize(about)
stemmed_words = [stemmer.stem(word) for word in words]




stemmed_words
# Out:
# ['I',
#  'love',
#  'gwenhwyfar',
#  'maragert',
#  'siev',
#  '.',
#  'I',
#  'will',
#  'marri',
#  'here',
#  'in',
#  'the',
#  'next',
#  '2',
#  'year',
#  'and',
#  'have',
#  'a',
#  'billion',
#  'babi',
#  'with',
#  'her',
#  '.']

# %%
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

about = """

I love Gwenhwyfar Maragert Sieve. I will marry here in the next 2 years and have a billion babies with her.
"""


lemmatizer.lemmatize("babies")
# Out:
# 'baby'

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer


about = """

I love Gwenhwyfar Maragert Sieve. I will marry here in the next 2 years and have a billion babies with her.
"""

News_tagged = word_tokenize(about)
nltk.pos_tag(about)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/conrad/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('\n', 'JJ'),
#  ('\n', 'NN'),
#  ('I', 'PRP'),
#  (' ', 'VBP'),
#  ('l', 'JJ'),
#  ('o', 'NN'),
#  ('v', 'NN'),
#  ('e', 'NN'),
#  (' ', 'NNP'),
#  ('G', 'NNP'),
#  ('w', 'VBD'),
#  ('e', 'JJ'),
#  ('n', 'JJ'),
#  ('h', 'NN'),
#  ('w', 'NN'),
#  ('y', 'NN'),
#  ('f', 'VBD'),
#  ('a', 'DT'),
#  ('r', 'NN'),
#  (' ', 'NNP'),
#  ('M', 'NNP'),
#  ('a', 'DT'),
#  ('r', 'NN'),
#  ('a', 'DT'),
#  ('g', 'NN'),
#  ('e', 'NN'),
#  ('r', 'NN'),
#  ('t', 'NN'),
#  (' ', 'NNP'),
#  ('S', 'NNP'),
#  ('i', 'NN'),
#  ('e', 'VBP'),
#  ('v', 'NN'),
#  ('e', 'NN'),
#  ('.', '.'),
#  (' ', 'NN'),
#  ('I', 'PRP'),
#  (' ', 'VBP'),
#  ('w', 'JJ'),
#  ('i', 'NN'),
#  ('l', 'VBP'),
#  ('l', 'NN'),
#  (' ', 'NNP'),
#  ('m', 'VBZ'),
#  ('a', 'DT'),
#  ('r', 'NN'),
#  ('r', 'NN'),
#  ('y', 'NN'),
#  (' ', 'NNP'),
#  ('h', 'NN'),
# ...

# %%
import nltk
nltk.download('tagsets')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize


about = """

I love Gwenhwyfar Maragert Sieve. I will marry here in the next 2 years and have a billion babies with her.
"""


nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...
